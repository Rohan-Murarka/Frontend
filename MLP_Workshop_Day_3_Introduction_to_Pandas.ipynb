# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-Murarka/Frontend/blob/main/MLP_Workshop_Day_3_Introduction_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the libraries

# %%
import numpy as np
import pandas as pd

# %%
manufacturer = ['Tata', 'Maruti','BMW']
model = ['Punch', 'Swift', 'S-class']
price_lacs = [10, 8, 20]
df = pd.DataFrame(data ={'manufacturer':manufacturer,
                            'model':model,
                            'price_lacs':price_lacs})

# %%
df
# Out:
#   manufacturer    model  price_lacs
# 0         Tata    Punch          10
# 1       Maruti    Swift           8
# 2          BMW  S-class          20

# %%
cars_data = df.to_numpy()

# %%
pd.DataFrame(data = cars_data,
             columns = ['manufacturer',
                            'model',
                            'price_lacs'])
# Out:
#   manufacturer    model price_lacs
# 0         Tata    Punch         10
# 1       Maruti    Swift          8
# 2          BMW  S-class         20

# %%
df['engine_size(cc)'] = [1100.9, 899.3, 1999.2]
# Out:
# <ipython-input-69-0e78168ef26c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine_size(cc)'] = [1100.9, 899.3, 1999.2]

# %%
df['Domestic'] =  [True, True, False]
# Out:
# <ipython-input-70-a51b44741af6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Domestic'] =  [True, True, False]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manufacturer     3 non-null      object
#  1   model            3 non-null      object
#  2   price_lacs       3 non-null      int64
#  3   engine_size(cc)  3 non-null      float64
#  4   Domestic         3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 227.0+ bytes

# %%
df = pd.read_csv('/content/vehicles.csv')
# Out:
# <ipython-input-22-036e5bd701b0>:1: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/vehicles.csv')

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %%
df[['barrels08', 'charge120']]
# Out:
# pandas.core.frame.DataFrame

# %%
df = df[['price_lacs', 'manufacturer', 'model' ]]

# %%
df[['manufacturer']]
# Out:
#   manufacturer
# 0         Tata
# 1       Maruti
# 2          BMW

# %%
df.index = [11, 12, 13]

# %%
df
# Out:
#     price_lacs manufacturer    model
# 11          10         Tata    Punch
# 12           8       Maruti    Swift
# 13          20          BMW  S-class

# %%
df.iloc[0]
# Out:
# price_lacs         10
# manufacturer     Tata
# model           Punch
# Name: 11, dtype: object

# %%
df.loc[[12, 11, 13]]
# Out:
#     price_lacs manufacturer    model
# 12           8       Maruti    Swift
# 11          10         Tata    Punch
# 13          20          BMW  S-class

# %%
df.iloc[[0, 2], [1, 2]]
# Out:
#    manufacturer    model
# 11         Tata    Punch
# 13          BMW  S-class

# %%
df.loc[[11, 13], ['manufacturer', 'model']]
# Out:
#    manufacturer    model
# 11         Tata    Punch
# 13          BMW  S-class

# %%
df.loc[[11, 13], 'manufacturer':'model']
# Out:
#    manufacturer    model
# 11         Tata    Punch
# 13          BMW  S-class

# %%
df.loc[14] = [14, 'Kia', 'Sonet', 1499.99, False]
# Out:
# <ipython-input-72-d845e425c4c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[14] = [14, 'Kia', 'Sonet', 1499.99, False]

# %%
tdf = df[['price_lacs', 'manufacturer', 'model', 'engine_size(cc)',]]

# %%
# df= df.drop(columns = ['engine_size(cc)', 'Domestic', 'model'],
#         )
tdf = df.drop(columns = ['engine_size(cc)', 'Domestic', 'model'],
        )
# Out:
#     price_lacs manufacturer
# 11          10         Tata
# 12           8       Maruti
# 13          20          BMW
# 14          14          Kia

# %%
tdf.drop(columns = ['model'],
         inplace=True)

# %%
tdf
# Out:
#     price_lacs manufacturer  engine_size(cc)
# 11          10         Tata          1100.90
# 12           8       Maruti           899.30
# 13          20          BMW          1999.20
# 14          14          Kia          1499.99

# %%
df.drop(index =[14])
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11          10         Tata    Punch           1100.9
# 12           8       Maruti    Swift            899.3
# 13          20          BMW  S-class           1999.2

# %%
df.iloc[0,0] = 9.0

# %%
df.iloc[0,1]
# Out:
# 'Tata'

# %%
df
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch          1100.90
# 12           8       Maruti    Swift           899.30
# 13          20          BMW  S-class          1999.20
# 14          14          Kia    Sonet          1499.99

# %%
df[[True, True, True, False]]
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch           1100.9
# 12           8       Maruti    Swift            899.3
# 13          20          BMW  S-class           1999.2

# %%
df.manufacturer =='Kia'
# Out:
# 11    False
# 12    False
# 13    False
# 14     True
# Name: manufacturer, dtype: bool

# %%
df[df.manufacturer !='Kia' df.price_lacs >5]
# Out:
# Index([14], dtype='int64')

# %%
(df.price_lacs > 8.5) &  (df.manufacturer !='Kia')
# Out:
# 11     True
# 12    False
# 13     True
# 14    False
# dtype: bool

# %%
df[~(df.price_lacs > 8.5)]
# and or not
# Out:
#     price_lacs manufacturer  model  engine_size(cc)
# 12           8       Maruti  Swift            899.3

# %%
df[(df.manufacturer=='Tata') | (df.manufacturer=='Maruti')|
(df.manufacturer=='BMW')]
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch           1100.9
# 12           8       Maruti    Swift            899.3
# 13          20          BMW  S-class           1999.2

# %%
df[df.manufacturer.isin(['Tata', 'Maruti', 'BMW'])]
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch           1100.9
# 12           8       Maruti    Swift            899.3
# 13          20          BMW  S-class           1999.2

# %%
df.manufacturer.isin(['Tata', 'Maruti', 'BMW'])
# Out:
# 11     True
# 12     True
# 13     True
# 14    False
# Name: manufacturer, dtype: bool

# %%
t = ['Tata', 'Maruti', 'BMW']

# %%
df.query("manufacturer !='Kia' and price_lacs > 8.5")
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch           1100.9
# 13          20          BMW  S-class           1999.2

# %%
not_kia_selector = lambda t: t.Company !='Kia'

# %%
df[not_kia_selector]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-bfa08b7e0956> in <cell line: 1>()
# ----> 1 df[not_kia_selector]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3714         check_dict_or_set_indexers(key)
#    3715         key = lib.item_from_zerodim(key)
# -> 3716         key = com.apply_if_callable(key, self)
#    3717
#    3718         if is_hashable(key) and not is_iterator(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     377     """
#     378     if callable(maybe_callable):
# --> 379         return maybe_callable(obj, **kwargs)
#     380
#     381     return maybe_callable
#
# <ipython-input-144-581964223a36> in <lambda>(t)
# ----> 1 not_kia_selector = lambda t: t.Company !='Kia'
#
# ...

# %%
tdf = df.copy()

# %%
tdf
# Out:
#     price_lacs manufacturer    model  engine_size(cc)
# 11           9         Tata    Punch          1100.90
# 12           8       Maruti    Swift           899.30
# 13          20          BMW  S-class          1999.20
# 14          14          Kia    Sonet          1499.99

# %%
tdf.price_lacs+=tdf.price_lacs*0.1

# %%
tdf.describe().T
# Out:
#                  count       mean        std    min       25%       50%  \
# price_lacs         4.0    14.0250    6.05000    8.8     9.625    12.650
# engine_size(cc)    4.0  1374.8475  485.34158  899.3  1050.500  1300.445
#
#                        75%     max
# price_lacs         17.0500    22.0
# engine_size(cc)  1624.7925  1999.2

# %%
# Method chaining

# %%
tdf['gst']= tdf.price_lacs*0.2

# %%
def compute_gst(a_row):
  if a_row

# %%
tdf.apply()
# Out:
#     price_lacs manufacturer    model  engine_size(cc)   gst
# 11         9.9         Tata    Punch          1100.90  1.98
# 12         8.8       Maruti    Swift           899.30  1.76
# 13        22.0          BMW  S-class          1999.20  4.40
# 14        15.4          Kia    Sonet          1499.99  3.08
